# %% [markdown]
# <a href="https://colab.research.google.com/github/trener26/kursAI/blob/main/wprowadzenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tekst

# %%
licznik = 1
while licznik <= 5:
  print(licznik)
  licznik += 1
# Out:
# 1
# 2
# 3
# 4
# 5
